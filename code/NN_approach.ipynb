# %% [markdown]
# # Notbook to solve the kaggle competition "Child Mind Institute - Detect Sleep States" with a neural network
# Link to the competition: https://www.kaggle.com/competitions/child-mind-institute-detect-sleep-states
#
#
# ### Install packages

# %%
import os, subprocess

try:
    subprocess.check_output('nvidia-smi')
    print('Nvidia GPU detected! Install torch for GPU')
    # !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117
except Exception: 
    print('No Nvidia GPU detected! Install torch for CPU')
    # !pip install torch torchvision torchaudio

# !pip install matplotlib seaborn pandas numpy wandb lightning

# %% [markdown]
# ### Import Weights and Biases and login
#
# To log in use your token generated by the weights and biases webpage within the `aichhs23` project.

# %%
import wandb

wandb.login()

# %%
# start a new wandb run to track this script
wandb.init(
    # set the wandb project where this run will be logged
    project="my-awesome-project",
    
    # track hyperparameters and run metadata
    config={
    "learning_rate": 0.02,
    "architecture": "CNN",
    "dataset": "CIFAR-100",
    "epochs": 10,
    }
)
